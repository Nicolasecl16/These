# %%
import tensorflow as tf
import tensorflow_probability as tfp
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import tensorboard
import ot
from statsmodels.distributions.empirical_distribution import ECDF
import Prob_models as PM
tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions
# Out:
# 2022-11-16 11:13:25.647915: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Metrics

# %% [markdown]
# ## QQplot

# %%
plt.figure()
plt.title('QQplot')
plt.scatter(tf.sort(samples_y),tf.sort(samples_rad))
plt.plot(tf.sort(samples_y),tf.sort(samples_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 plt.figure()
#       2 plt.title('QQplot')
# ----> 3 plt.scatter(tf.sort(samples_y),tf.sort(samples_rad))
#       4 plt.plot(tf.sort(samples_y),tf.sort(samples_y))
#
# NameError: name 'samples_y' is not defined

# %% [markdown]
# ### KL divergence upon a threshold

# %%
def tail_mod(f,n,x):
    return((n/n+1)*(1-f(x))+1/(n+1))



def L(X,Y,u):
    Nn = np.sum(X>u)
    m=Y.shape[0]
    fY=ECDF(Y)
    Xmax = np.maximum(X,u)
    Xu = np.minimum(Xmax,u)
    res = 1 + 1/Nn*(np.sum(np.log(tail_mod(fY,m,Xmax)/tail_mod(fY,m,Xu))))
    return(res)
    
def K(X,Y,u):
    res = -L(X,Y,u)-L(Y,X,u)
    return res

# %% [markdown]
# ### Wasserstein distance

# %%
def Wasserstein(s1,s2):
    M=ot.dist(s1,s2)
    return(ot.emd2())

# %% [markdown]
# ### Threshold selection

# %%
def distmat(X):
    r = tf.reduce_sum(X*X, 1)
    r = tf.reshape(r, [-1, 1])
    D = r - 2*tf.matmul(X, tf.transpose(X)) + tf.transpose(r)
    return(tf.maximum(D,0))

def T(X,Y,n):
    MX = tf.math.sqrt(distmat(X))
    MY = tf.math.sqrt(distmat(Y))
    T1 = (1/n**2)*tf.reduce_sum(tf.math.multiply(MX,MY))
    T2 = (2/n**3)*tf.reduce_sum(tf.linalg.matmul(MX,MY))
    T3 = (1/n**4)*tf.reduce_sum(tf.tensordot(MX,MY,axes=0))
    return T1-T2+T3

# %%
#pvalues for given radii sorted R_sort and associated angles angle_dep
nbq = 30
qmax=0.15
qmin=0.4
m=60
L=200
qk = np.arange(qmax,qmin,(qmin-qmax+0.001)/nbq)
nk = 500*qk
res=[]


for i in range(nbq):
    pvi = 0
    for k in range(m):
        q = qk[i]
        n = nk[i]
        r = R1_sort[np.int((1-q)*10000)].numpy()
        Ind = tf.cast(tf.where(R>r),dtype=tf.int32)
        Rq = R[Ind]/r
        angle = angle_dep[Ind]
        IndS = np.random.permutation(Ind[0])[:np.int(n)]
        RqS_joint = (R[IndS]/r)
        shape_RqS=RqS_joint.shape[0]
        RqS_joint = tf.reshape(RqS_joint,(shape_RqS,1))
        angleS_joint = (angle_dep[IndS])
        T_emp = T(RqS_joint,angleS_joint,np.int(n))
        pvk=0
        for j in range(L):
            RqS_ind=np.random.permutation(Rq)[:np.int(n)]
            RqS_ind = np.expand_dims(RqS_ind,axis=-1)
            angleS_ind = np.random.permutation(angle)[:np.int(n)]
            T_ind = T(RqS_ind,angleS_ind,np.int(n))
            pvk+= T_emp.numpy()>(T_ind.numpy())
        pvk = pvk/L
        pvi+=pvk
    pvi = pvi/m
    res.append(pvi)

# %% [markdown]
# # Radius experiment

# %%
checkpoint_path = '/home/nlafon/These/Extreme_VAE/tmp/radius1/Ext_VAE/Learnable_prior2/U_Ext_VAE_checkpoint'
import Prob_models as PM
#vae_test = PM.Std_VAE()
#vae_test = PM.Ext_VAE()
vae_test = PM.U_Ext_VAE()
vae_test.load_weights(checkpoint_path)
# Out:
# <tf.Variable 'prior_c:0' shape=(1,) dtype=float32, numpy=array([1.8495123], dtype=float32)>
# 2022-11-15 10:17:32.407353: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-15 10:17:32.408966: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
print(vae_test.encoder.prior.rate)
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32)

# %%
# Samples from R1
N_samples = 10000
A = 2*tfd.Uniform().sample(N_samples)
X = tfd.InverseGamma(concentration =1.5, scale = 0.6 ).sample(N_samples)
test_set = A*X
test_set =test_set.numpy()
# Out:
# 2022-11-16 11:13:35.135309: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 11:13:35.138153: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Samples from R2
N_samples = 10000
Ber = tfd.Bernoulli(probs=0.3, dtype ='float').sample(N_samples) 
IG1 = tfd.InverseGamma(concentration =1.8, scale = 1 ).sample(N_samples)
IG2 = tfd.InverseGamma(concentration =1.8, scale = 1 ).sample(N_samples)
R2 = IG1*Ber +(6+IG2)*(1-Ber)

# %%
prior_samples = vae_test.encoder.prior.sample(N_samples)
print(tf.reduce_min(prior_samples))
samples_vae = vae_test.decoder(prior_samples).sample()
print(samples_vae)
# Out:
# tf.Tensor(0.006908016, shape=(), dtype=float32)
# tf.Tensor([0.03377771 0.45500216 1.5105833  ... 1.2426504  0.7933997  2.5655055 ], shape=(10000,), dtype=float32)

# %%
print(tf.reduce_max(samples_vae))
print(tf.reduce_max(test_set))
print(samples_vae.shape)
# Out:
# tf.Tensor(218.8282, shape=(), dtype=float32)
# tf.Tensor(313.66684, shape=(), dtype=float32)
# (10000,)

# %%
sns.distplot(samples_vae)
plt.title("empirical density from generated samples")
plt.show()

sns.distplot(test_set)
plt.title("empirical density from true samples")
plt.show()
# Out:
# /tmp/ipykernel_51558/2358292155.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples_vae)
# /tmp/ipykernel_51558/2358292155.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(test_set)

# %%
plt.figure()
plt.title('QQplot')
plt.scatter(tf.sort(test_set),tf.sort(samples_vae))
plt.plot(tf.sort(test_set),tf.sort(test_set))

# %%
print(samples_vae.shape)
plt.figure()
plt.title('log-QQplot')
plt.scatter(tf.math.log(tf.sort(test_set[5000:])),tf.math.log(tf.sort(samples_vae)[5000:]))
plt.plot(tf.math.log(tf.sort(test_set)[5000:]),tf.math.log(tf.sort(test_set)[5000:]))
# Out:
# (10000,)

# %%
#Kl divergence upon a threshold
q = 0.9
u=tf.sort(test_set)[int(q*N_samples)]
print(u)
print(f"KL divergence upon threshold {q} :  {K(test_set,samples_vae,u)}")

X = np.arange(0,1,0.01)
Ind = X*10000
Ind = Ind.astype('int64')

Q = np.sort(samples_vae)[Ind]
#Q = np.sort(test_set)[Ind]

Y = [K(test_set,samples_vae,qi) for qi in Q]
plt.figure()
plt.title("KL divergence upon threshold u")
plt.xlabel("u")
plt.ylabel("KL upon u")
plt.plot(X,Y)
# Out:
# tf.Tensor(2.1701174, shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [82], in <cell line: 5>()
#       3 u=tf.sort(test_set)[int(q*N_samples)]
#       4 print(u)
# ----> 5 print(f"KL divergence upon threshold {q} :  {K(test_set,samples_vae,u)}")
#       7 X = np.arange(0,1,0.01)
#       8 Ind = X*10000
#
# NameError: name 'K' is not defined

# %%
tfd.kl_divergence(tfd.Gamma(concentration =1.5, rate = 0.8 ),tfd.Gamma(concentration =1.5, rate = 10 ))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=13.461407>

# %%
U = vae_test.encoder(tf.expand_dims(np.arange(1,1000,1),-1)).concentration
print(U[898])
print(U[998])
print(tf.sort(prior_samples[:,0]))
c_vae = vae_test.decoder((np.arange(0.01,10,0.01,dtype = float))).concentration
plt.plot(c_vae)
plt.figure()
r_vae = vae_test.decoder((np.arange(0.01,10,0.01,dtype = float))).rate
plt.plot(r_vae)
# Out:
# tf.Tensor(2.0352774, shape=(), dtype=float32)
# tf.Tensor(2.067609, shape=(), dtype=float32)
# tf.Tensor(
# [1.1399835e-02 1.7457796e-02 2.0310830e-02 ... 1.1243185e+01 1.1697983e+01
#  1.2875702e+01], shape=(10000,), dtype=float32)

# %% [markdown]
# # Angle experiment

# %% [markdown]
# ## Samples from the sphere

# %%
def alphas_function(x):
    res = tf.convert_to_tensor([6. -3.*tf.minimum(1.,0.5/x), 6. -3.*tf.minimum(1.,0.5/x) , 3.+ 3.*tf.minimum(1.,0.5/x), 3.+ 3.*tf.minimum(1.,0.5/x), 3.+ 3.*tf.minimum(1.,0.5/x)])
    return(tf.transpose(res))


alphas          = alphas_function(test_set)
angle_train_dep = tfd.Dirichlet(alphas).sample()

# %%
Ind       = tf.argsort(test_set)
R1_sort   = test_set[Ind]
angle_dep = angle_train_dep.numpy()[Ind]

# %% [markdown]
# ## Independence between radius and angle

# %%
nbq = 100
qmax=0.01
qmin=0.3
m=60
L=200

qk = np.arange(qmax,qmin,(qmin-qmax+0.001)/nbq)
nk = 500*qk
res=[]

for i in range(nbq):
    print(i)
    pvi = 0
    q = qk[i]
    indq =int((1-q)*10000)
    n = int(nk[i])
    r = R1_sort[indq]
    print(r)
    print(q)
    Rq = R1_sort[indq:]/r
    angle = angle_dep[indq:]
    Nq = 10000-indq
    start=datetime.now()
    for k in range(m):
        IndS = tf.random.shuffle(tf.range(start=0, limit=Nq, dtype=tf.int32))[:n]
        RqS_joint = tf.gather(Rq,IndS)
        RqS_joint = tf.reshape(RqS_joint,(n,1))
        angleS_joint = tf.gather(angle,IndS)
        T_emp = T(RqS_joint,angleS_joint,int(n))
        pvk=0
        for j in range(L):
            RqS_ind=tf.random.shuffle(Rq)[:int(n)]
            RqS_ind = tf.reshape(RqS_ind,(n,1))
            angleS_ind = tf.random.shuffle(angle)[:int(n)]
            T_ind = T(RqS_ind,angleS_ind,int(n))
            pvk+= T_emp.numpy()<(T_ind.numpy())
        pvk = pvk/L
        pvi+=pvk
    print(datetime.now()-start)
    pvi = pvi/m
    res.append(pvi)
    print(qk[i])
    print(pvi)
# Out:
# 5.0
# 0
# 11.662653
# 0.01
# 0:00:36.950672
# 0.01
# 0.5296666666666666
# 1
# 9.452605
# 0.01291
# 0:00:39.415701
# 0.01291
# 0.5115833333333334
# 2
# 8.26112
# 0.01582
# 0:00:39.559343
# 0.01582
# 0.47958333333333336
# 3
# 7.1656604
# 0.018729999999999997
# 0:00:39.696202
# 0.018729999999999997
# 0.49541666666666645
# 4
# 6.441404
# 0.02164
# 0:00:39.970709
# 0.02164
# 0.5010833333333334
# 5
# 6.006533
# 0.024549999999999995
# 0:00:40.017996
# 0.024549999999999995
# 0.48866666666666675
# 6
# 5.6119814
# 0.02746
# 0:00:40.241863
# 0.02746
# 0.4594166666666667
# 7
# 5.2860894
# 0.030369999999999994
# 0:00:42.751884
# 0.030369999999999994
# 0.46575000000000016
# 8
# 4.927922
# 0.03328
# 0:00:43.229898
# 0.03328
# 0.5281666666666667
# 9
# 4.655313
# 0.03618999999999999
# 0:00:44.881946
# 0.03618999999999999
# 0.5016666666666666
# 10
# 4.3762836
# 0.039099999999999996
